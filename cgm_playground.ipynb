# %%
from hypnospy import CGM
from hypnospy import Wearable, Diary
from hypnospy.data import MESAPreProcessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %reload_ext autoreload
# %autoreload 2

cgm_path = './data/cgm/glucose.31.1.20.csv'
wearable_path = "./data/examples_mesa/mesa-sample.csv"
preprocessed = MESAPreProcessing(wearable_path)

# Wearable is the main object in HypnosPy.
w = Wearable(preprocessed)
w.data['mesaid']=-1
cgm = CGM().from_file(cgm_path)

w.add_cgm(cgm)

print(w.data.columns)
print(w.data.head(10))


#df = pd.read_csv(cgm_path, header=1)

#print(df.columns)
#print(df.dtypes)
#print(df.head)

#cgm = CGM().from_file(cgm_path)

#print(cgm)
#print(cgm.data.columns)
#print(cgm.data.head(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     455             try:
# --> 456                 values, tz = conversion.datetime_to_datetime64(arg)
#     457                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-80e17f5a8363> in <module>
#       9 w = Wearable(preprocessed)
#      10 w.data['mesaid']=-1
# ---> 11 cgm = CGM().from_file(cgm_path)
# ...

# %%
print(w.data['pid'].sum())

#print(w.data['hyp_time_col_cgm'].describe())
#plt.plot(w.data['gluc_mgdl'])
#plt.show()
# Out:
# 0.0

# %%
print(cgm.data['glucose_mgdl'])
#print(cgm.data.index.dtype)
plt.plot(cgm.data[cgm.data['auto0_man1_read']==0]['glucose_mgdl'])
plt.plot(cgm.data[cgm.data['auto0_man1_read']==1]['glucose_mgdl'])
plt.show()
# Out:
# cgm_timestamp
# 2018-11-29 11:29:00     82.0
# 2018-11-29 11:44:00     85.0
# 2018-11-29 11:59:00     95.0
# 2018-11-29 12:14:00    113.0
# 2018-11-29 12:29:00     90.0
#                        ...
# 2020-01-30 07:00:00      0.0
# 2020-01-30 17:06:00      0.0
# 2020-01-30 20:01:00      0.0
# 2020-01-31 05:39:00      0.0
# 2020-01-31 05:39:00      0.0
# Name: glucose_mgdl, Length: 21158, dtype: float64

# %%
df_wearable = pd.date_range(start='29/11/2018', periods=1000, freq='M')
